# %% [markdown]
# <h3 style="text-align: center; background-color: #5AA647; color: white; padding: 8px; border-radius: 6px;">
# NLP - Sentiment Analysis using WhatsApp chat
# </h3>

# %% [markdown]
# <div style="
#     border:2px solid #4CAF50;
#     padding:20px;
#     border-radius:10px;
#     width:550px;
#     background-color:#f9f9f9;
#     font-family:Arial;
# ">
#
# <h2 style="margin-top:0;">Sentiment Analysis in NLP — Simple Explanation</h2>
#
# <p>
# Sentiment analysis means finding out the emotion or opinion in a piece of text.
# </p>
#
# <p>
# 👉 <strong>In very simple terms:</strong><br>
# It answers the question —
# <em>Is this text positive, negative, or neutral?</em>
# </p>
#
# <h3>✅ Example</h3>
# <ul>
#     <li>“This product is amazing!” → <b style="color:green;">Positive 😊</b></li>
#     <li>“I hate the service.” → <b style="color:red;">Negative 😡</b></li>
#     <li>“The product arrived yesterday.” → <b style="color:gray;">Neutral 😐</b></li>
# </ul>
#
# <h3>💡 How it works</h3>
# <ul>
#     <li>Looks at the words used</li>
#     <li>Understands tone</li>
#     <li>Classifies sentiment</li>
# </ul>
#
# <h3>🧠 Where it is used</h3>
# <ul>
#     <li>Customer feedback</li>
#     <li>Product reviews</li>
#     <li>Social media</li>
#     <li>Chatbots</li>
# </ul>
#
# </div>

# %%
import pandas as pd

# %%
df = pd.read_csv("mabel.txt",header=None,encoding='utf8', on_bad_lines='skip')

# %%
# Remove the first row (often unwanted header or metadata row)
df = df.drop(0)

# Rename the columns to 'Date' and 'Chat'
df.columns = ['Date', 'Chat']

# Split the 'Chat' column into two parts using '-' as separator
# n=1 ensures only the first '-' is used for splitting
# expand=True creates separate columns
Message = df["Chat"].str.split("-", n=1, expand=True)

# Assign the first part of the split to a new column 'Time'
df["Time"] = Message[0]

# Now split the second part again using ':' to separate Name and message text
Message1 = Message[1].str.split(":", n=1, expand=True)

# Assign the first part as 'Name' (person who sent the message)
df["Name"] = Message1[0]

# Assign the second part as the actual chat message
df["Chat"] = Message1[1]

# Reorder/select only the required columns in the desired order
df = df[["Date", "Time", "Name", "Chat"]]

# Display the final cleaned DataFrame
df
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 1 to 50
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    50 non-null     object
#  1   Time    50 non-null     object
#  2   Name    50 non-null     object
#  3   Chat    50 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dataset=df

# %%
dataset.dropna(inplace=True)

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\xsanthkum\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
#sid = SentimentIntensityAnalyzer()

# %%
#senti=sid.polarity_scores(dataset['Chat'][4])

# %%
#senti

# %%
def sentimentalAnalysis(data, columnname):
    
    # Import visualization libraries
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    # Import Sentiment Analyzer from NLTK (VADER)
    from nltk.sentiment.vader import SentimentIntensityAnalyzer
    
    # Initialize the sentiment analyzer
    sid = SentimentIntensityAnalyzer()
    
    # Remove rows with null or empty values (data cleaning)
    data.dropna(inplace=True)
    
    # Example check (commented): Get sentiment score for a specific row
    # sid.polarity_scores(data[columnname][93])
    
    # Create a new column 'scores' that stores sentiment dictionary for each comment
    # Output example: {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.8}
    data['scores'] = data[columnname].apply(
        lambda commentText: sid.polarity_scores(commentText)
    )
    
    # Extract 'compound' score (overall sentiment score)
    data['compound'] = data['scores'].apply(
        lambda score_dict: score_dict['compound']
    )
    
    # Extract individual sentiment scores into separate columns
    data['Negative'] = data['scores'].apply(
        lambda score_dict: score_dict['neg']
    )
    
    data['Positive'] = data['scores'].apply(
        lambda score_dict: score_dict['pos']
    )
    
    data['Neutral'] = data['scores'].apply(
        lambda score_dict: score_dict['neu']
    )
    
    # Create a final label based on compound score
    # If compound >= 0 → Positive, else Negative
    data['comp_score'] = data['compound'].apply(
        lambda c: 'pos' if c > 0 else ('neg' if c < 0 else 'neutral')
    )
    
    # Clear any previous plots (optional cleanup)
    plt.clf()
    
    # (Optional - currently commented)
    # Create count plot for sentiment by Name
    # comp = sns.countplot(x='comp_score', hue='Name', data=data, palette='magma')
    # comp.figure.savefig("date_charts.png")
    
    # Count how many positive and negative values
    posneg = pd.DataFrame(data['comp_score'].value_counts())
    
    # Return both summary (pos/neg count) and full processed data
    return posneg, data

# %%
pos,data_Senti=sentimentalAnalysis(dataset,columnname='Chat')

# %%
data_Senti
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# ...

# %%
pos
# Out:
#             count
# comp_score
# neutral        26
# pos            22
# neg             2
